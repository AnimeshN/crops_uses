# %%
kharif_1 = ['खरीप ज्वारी','बाजरी','मुग','उडिद','तीळ','सोयाबीन','मका','खरीप भुईमुग','खरीप सुर्यफुल','खरीप चारा पिके','खरीप भात','नागली','वरई','वाल','Others']
kharif_2_ = ['कांदा','मिरची','वांगे','टोमेटो','फुल कोबी','बटाटा','भेंडी','भाजीपाला','Others']
kharif_3 = ['तूर','हळद','आले','कापूस']
rabi_4 = ['रबी ज्वारी','हरभरा','गहू','मका','करडई','मोहोरी','रब्बी इतर गळीत','रबी भुईमुग','रबी सुर्यफुल','रबी चारा पिके','उन्हाळी भुईमुग','उन्हाळी सुर्यफुल','Others']
rabi_5 = ['कांदा','मिरची','वांगे','टोमेटो','फुल कोबी','बटाटा','भेंडी','भाजीपाला']
summer_7 = rabi_5
annual_8 = ['आंबा','काजू','नारळ','सीताफळ','सुपारी','चिकू','पेरू','बोर','द्राक्ष','केळी','डाळिंब','लिंबू वर्गीय झाडे (संत्र, मोसंबी इ.)','ऊस (आडसाली) - जानेवारी पेरणी','ऊस (सुरु) - जानेवारी पेरणी','ऊस (पूर्व हंगामी) - ऑक्टोबर','Others']

# %%
import pandas as pd

df = pd.read_excel('Basic Info _ CP Data Eklahare_TCA.xlsx', sheet_name=None) # can also index sheet by name or fetch all sheets

# %%
village_name = "Eklahare"

# %%
my_df = df['2018'][['खरीप प्रमुख पिके','total_cultivable_area']].values.tolist()

# %%
my_df
# Out:
# [['खरीप ज्वारी', 21.8129],
#  ['खरीप भुईमुग', 27.2167],
#  ['बाजरी', 136.1494],
#  ['मका', 245.0821],
#  ['सोयाबीन', 87.11980000000001],
#  ['खरीप भाजीपाला पिके', 'total_cultivable_area'],
#  ['Others', 21.8129],
#  ['फ्लॉवर', 5.4697],
#  ['वाटाणा', 65.3728],
#  ['दीर्घ खरीप पिके', nan],
#  ['रब्बी प्रमुख पिके', 'total_cultivable_area'],
#  ['गहू', 114.4024],
#  ['हरभरा', 21.8129],
#  ['रब्बी भाजीपाला पिके', 'total_cultivable_area'],
#  ['कांदा', 348.5451],
#  ['उन्हाळी प्रमुख पिके', 'total_cultivable_area'],
#  [' ', 0],
#  ['उन्हाळी भाजीपाला पिके', nan],
#  ['वार्षिक व बहुवर्षीय पिके', 'total_cultivable_area'],
#  ['पेरू', 21.8129],
#  ['सीताफळ', 21.8129]]

# %%
length = len(my_df)

# %%
for i in range(length):
    if my_df[i][0] == 'खरीप भाजीपाला पिके':
        a = i
    if my_df[i][0] == 'दीर्घ खरीप पिके':
        b = i
    if my_df[i][0] == 'रब्बी प्रमुख पिके':
        c = i
    if my_df[i][0] == 'रब्बी भाजीपाला पिके':
        d = i
    if my_df[i][0] == 'उन्हाळी प्रमुख पिके':
        e = i
    if my_df[i][0] == 'उन्हाळी भाजीपाला पिके':
        f = i
    if my_df[i][0] == 'वार्षिक व बहुवर्षीय पिके':
        g = i
print(a,b,c,d,e,f,g)
# Out:
# 5 9 10 13 15 17 18

# %%
K1,K2,K3,R4,R5,S6,S7,A8 = [],[],[],[],[],[],[],[]
for i in range(length):
    if i < a:
        K1.append([my_df[i][0],my_df[i][1]])
    elif (i > a and i < b):
        K2.append([my_df[i][0],my_df[i][1]])
    elif (i > b and i < c):
        K3.append([my_df[i][0],my_df[i][1]])
    elif (i > c and i < d):
        R4.append([my_df[i][0],my_df[i][1]])
    elif (i > d and i < e):
        R5.append([my_df[i][0],my_df[i][1]])
    elif (i > e and i < f):
        S6.append([my_df[i][0],my_df[i][1]])
    elif (i > f and i < g):
        S7.append([my_df[i][0],my_df[i][1]])
    elif (i > g):
        A8.append([my_df[i][0],my_df[i][1]])

# %%
print(K1)
# Out:
# [['खरीप ज्वारी', 21.8129], ['खरीप भुईमुग', 27.2167], ['बाजरी', 136.1494], ['मका', 245.0821], ['सोयाबीन', 87.11980000000001]]

# %%
mymaster = [['खरीप ज्वारी'],['बाजरी'],['मुग'],['उडिद'],['तीळ'],['सोयाबीन'],['मका'],['खरीप भुईमुग'],['खरीप सुर्यफुल'],['खरीप चारा पिके'],['खरीप भात'],['नागली'],['वरई'],['वाल'],['Others']]
for i in range(len(K1)):
#     print(K1[i][0])
    for j in range(len(mymaster)):
#         print(mymaster[j][0])
        if K1[i][0] == mymaster[j][0]:
            mymaster[j].append(K1[i][1])
            break

# %%
print(mymaster)
# Out:
# [['खरीप ज्वारी', 21.8129], ['बाजरी', 136.1494], ['मुग'], ['उडिद'], ['तीळ'], ['सोयाबीन', 87.11980000000001], ['मका', 245.0821], ['खरीप भुईमुग', 27.2167], ['खरीप सुर्यफुल'], ['खरीप चारा पिके'], ['खरीप भात'], ['नागली'], ['वरई'], ['वाल'], ['Others']]

# %%
df['2018']
# Out:
#             खरीप प्रमुख पिके  area_kharif_major_1  \
# 0                खरीप ज्वारी                    1
# 1                खरीप भुईमुग                 1.25
# 2                      बाजरी                 6.25
# 3                        मका                11.25
# 4                    सोयाबीन                    4
# 5         खरीप भाजीपाला पिके   area_kharif_vegi_2
# 6                     Others                    1
# 7                     फ्लॉवर                 0.25
# 8                     वाटाणा                    3
# 9            दीर्घ खरीप पिके   area_Kharif_long_3
# 10         रब्बी प्रमुख पिके     area_rabi_main_4
# 11                       गहू                 5.25
# 12                     हरभरा                    1
# 13       रब्बी भाजीपाला पिके     area_rabi_vegi_5
# 14                     कांदा                   16
# 15       उन्हाळी प्रमुख पिके  area_summer_major_6
# 16                                              0
# 17     उन्हाळी भाजीपाला पिके   area_summer_vegi_7
# 18  वार्षिक व बहुवर्षीय पिके        area_annual_8
# 19                      पेरू                    1
# 20                    सीताफळ                    1
#
#     crop_area_per_holding_sample  total_cultivable_area
# 0                         0.0331                21.8129
# 1                         0.0413                27.2167
# 2                         0.2066                136.149
# 3                         0.3719                245.082
# 4                         0.1322                87.1198
# 5   crop_area_per_holding_sample  total_cultivable_area
# 6                         0.0331                21.8129
# 7                         0.0083                 5.4697
# 8                         0.0992                65.3728
# 9                            NaN                    NaN
# 10  crop_area_per_holding_sample  total_cultivable_area
# 11                        0.1736                114.402
# 12                        0.0331                21.8129
# 13  crop_area_per_holding_sample  total_cultivable_area
# 14                        0.5289                348.545
# 15  crop_area_per_holding_sample  total_cultivable_area
# 16                             0                      0
# 17                           NaN                    NaN
# 18  crop_area_per_holding_sample  total_cultivable_area
# 19                        0.0331                21.8129
# 20                        0.0331                21.8129

# %%
output = pd.read_excel('Master.xlsx', sheet_name=None) # can also index sheet by name or fetch all sheets

# %%
output['Sheet1']
# Out:
#                   Unnamed: 0  खरीप ज्वारी  बाजरी  \
# 0                   Atkawade          NaN    NaN
# 1                   Bhatwadi          NaN    NaN
# 2                 Chandrapur          NaN    NaN
# 3                    Chondhi          NaN    NaN
# 4                      Dapur          NaN    NaN
# 5                      Datli          NaN    NaN
# 6                 Dattanagar          NaN    NaN
# 7                     Deopur          NaN    NaN
# 8                 Dharangaon          NaN    NaN
# 9                   Dhondbar          NaN    NaN
# 10             Dhondvirnagar          NaN    NaN
# 11                    Dubere          NaN    NaN
# 12                  Eklahare          NaN    NaN
# 13                  Fardapur          NaN    NaN
# 14                     Gonde          NaN    NaN
# 15                   Gulapur          NaN    NaN
# 16                  Gulvanch          NaN    NaN
# 17                  Gurewadi          NaN    NaN
# 18                   Harsule          NaN    NaN
# 19                   Jamgaon          NaN    NaN
# 20           Jayprakashnagar          NaN    NaN
# 21                  Kedarpur          NaN    NaN
# 22                Khadangali          NaN    NaN
# 23                  Khambale          NaN    NaN
# 24                 Khaparale          NaN    NaN
# 25               Khopadi Bk.          NaN    NaN
# 26               Khopadi Kh.          NaN    NaN
# 27                Kirtangali          NaN    NaN
# 28                   Konambe          NaN    NaN
# 29              Krishnanagar          NaN    NaN
# 30           Kundewadi Majre          NaN    NaN
# 31           Kundewadi Mauje          NaN    NaN
# 32                  Malegaon          NaN    NaN
# 33                  Manegaon          NaN    NaN
# 34                 Maparwadi          NaN    NaN
# 35                    Mendhi          NaN    NaN
# 36                 Musalgaon          NaN    NaN
# 37            Nimgaon Sinner          NaN    NaN
# 38                  Panchale          NaN    NaN
# 39                     Paste          NaN    NaN
# 40                    Patole          NaN    NaN
# 41                Pimpalgaon          NaN    NaN
# 42                  Ramnagar          NaN    NaN
# 43                   Sangavi          NaN    NaN
# 44                 Saradwadi          NaN    NaN
# 45                  Shahapur          NaN    NaN
# 46  Shastrinagar (Lonarwadi)          NaN    NaN
# 47              Shivajinagar          NaN    NaN
# 48                  Somthane          NaN    NaN
# 49                   Sonambe          NaN    NaN
# 50                    Sonari          NaN    NaN
# 51                    Ujjani          NaN    NaN
# 52                 Vadangali          NaN    NaN
# 53            Wadgaon Sinnar          NaN    NaN
#
#     मुग, मठ, चवळी, उडिद, \nकुलीद  तीळ  सोयाबीन  मका  मका चारा  खरीप भुईमुग  \
# 0                            NaN  NaN      NaN  NaN       NaN          NaN
# 1                            NaN  NaN      NaN  NaN       NaN          NaN
# 2                            NaN  NaN      NaN  NaN       NaN          NaN
# 3                            NaN  NaN      NaN  NaN       NaN          NaN
# 4                            NaN  NaN      NaN  NaN       NaN          NaN
# 5                            NaN  NaN      NaN  NaN       NaN          NaN
# 6                            NaN  NaN      NaN  NaN       NaN          NaN
# 7                            NaN  NaN      NaN  NaN       NaN          NaN
# 8                            NaN  NaN      NaN  NaN       NaN          NaN
# 9                            NaN  NaN      NaN  NaN       NaN          NaN
# 10                           NaN  NaN      NaN  NaN       NaN          NaN
